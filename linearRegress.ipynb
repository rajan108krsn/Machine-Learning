# %%
import numpy as np
print("NumPy imported successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import numpy as np
#       2 print("NumPy imported successfully")
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import sys
print(f"Python: {sys.version}")
print(f"Executable: {sys.executable}")
# Out:
# Python: 3.13.3 (v3.13.3:6280bb54784, Apr  8 2025, 10:47:54) [Clang 15.0.0 (clang-1500.3.9.4)]
# Executable: /Users/madhavkrsn/Desktop/MachineLearning/.venv/bin/python

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split 

#sklearn lib se model_selection module se train test split function split kro

#A module is a single Python file, while a library is a collection of multiple modules designed to perform related tasks
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'pandas'

# %%
print('Govind Govind')
# Out:
# Govind Govind

# %%
df = pd.read_csv('insurance.csv')
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_csv('insurance.csv')
#       2 print(df)
#
# NameError: name 'pd' is not defined

# %%
X = df[['age','sex','bmi','children','smoker','region']] #features
y = df['charges']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 X = df[['age','sex','bmi','children','smoker','region']] #features
#       2 y = df['charges']
#
# NameError: name 'df' is not defined
